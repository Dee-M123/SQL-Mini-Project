# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Dee-M123/SQL-Mini-Project/refs/heads/main/DATA/Cleaned%20Data/coffee_sales_sql_ready.csv")

# %%
df.head(3)
# Out:
#    transaction_id transaction_date transaction_time  store_id store_location  \
# 0          114301       2023-06-01         11:33:29         3        Astoria
# 1          115405       2023-06-02         11:18:24         3        Astoria
# 2          115478       2023-06-02         12:02:45         3        Astoria
#
#    product_id  transaction_qty  unit_price  total_bill product_category  \
# 0          45                1         3.0         3.0              Tea
# 1          45                1         3.0         3.0              Tea
# 2          45                1         3.0         3.0              Tea
#
#         product_type product_detail   size month_name  day_name  hour  month  \
# 0  Brewed herbal tea     Peppermint  Large       June  Thursday    11      6
# 1  Brewed herbal tea     Peppermint  Large       June    Friday    11      6
# 2  Brewed herbal tea     Peppermint  Large       June    Friday    12      6
#
#    day_of_week
# 0            3
# 1            4
# ...

# %%
df.shape
# Out:
# (149116, 18)

# %%
df.columns = (df.columns
      .str.strip()
      .str.lower()
      .str.replace(' ', '_'))

# %%
df.head(2)
# Out:
#    transaction_id transaction_date transaction_time  store_id store_location  \
# 0          114301       2023-06-01         11:33:29         3        Astoria
# 1          115405       2023-06-02         11:18:24         3        Astoria
#
#    product_id  transaction_qty  unit_price  total_bill product_category  \
# 0          45                1         3.0         3.0              Tea
# 1          45                1         3.0         3.0              Tea
#
#         product_type product_detail   size month_name  day_name  hour  month  \
# 0  Brewed herbal tea     Peppermint  Large       June  Thursday    11      6
# 1  Brewed herbal tea     Peppermint  Large       June    Friday    11      6
#
#    day_of_week
# 0            3
# 1            4

# %%
df["transaction_date"].isna().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# transaction_id      0
# transaction_date    0
# transaction_time    0
# store_id            0
# store_location      0
# product_id          0
# transaction_qty     0
# unit_price          0
# total_bill          0
# product_category    0
# product_type        0
# product_detail      0
# size                0
# month_name          0
# day_name            0
# hour                0
# month               0
# day_of_week         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **We have established that we have duplicated rows and no null values, so we can create our tables for SQL**

# %%
stores = df[['store_id', 'store_location']].drop_duplicates()

# %%
stores.shape
# Out:
# (3, 2)

# %%
stores.to_csv("stores_sql.csv", index=False)

# %%
products = df[['product_id', 'product_category', 'product_type',
     'product_detail', 'size', 'unit_price']
].drop_duplicates()

# %%
products.to_csv("products_sql.csv", index=False)

# %%
transactions = df[['transaction_id', 'transaction_date', 'transaction_time',
     'store_id', 'product_id',"transaction_qty", 'total_bill',
     'hour', 'day_name', 'month', 'month_name', 'day_of_week']
]

# %%
transactions.to_csv("transactions_sql.csv", index=False)
